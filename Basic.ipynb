# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %%
dataset = pd.read_csv(r'C:\Users\Bhargav Patel\Desktop\Machine learning_jupyter_notebook\Machine_Learning_Data_Preprocessing_Python-master\MallCustomers.csv')
dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
dataset.shape
# Out:
# (200, 5)

# %%
x = dataset.iloc[:,:-1].values
x
# Out:
# array([[1, 'Male', 19, 15],
#        [2, 'Male', 21, 15],
#        [3, 'Female', 20, 16],
#        [4, 'Female', 23, 16],
#        [5, 'Female', 31, 17],
#        [6, 'Female', 22, 17],
#        [7, 'Female', 35, 18],
#        [8, 'Female', 23, 18],
#        [9, 'Male', 64, 19],
#        [10, 'Female', 30, 19],
#        [11, 'Male', 67, 19],
#        [12, 'Female', 35, 19],
#        [13, 'Female', 58, 20],
#        [14, 'Female', 24, 20],
#        [15, 'Male', 37, 20],
#        [16, 'Male', 22, 20],
#        [17, 'Female', 35, 21],
#        [18, 'Male', 20, 21],
#        [19, 'Male', 52, 23],
#        [20, 'Female', 35, 23],
#        [21, 'Male', 35, 24],
#        [22, 'Male', 25, 24],
#        [23, 'Female', 46, 25],
#        [24, 'Male', 31, 25],
#        [25, 'Female', 54, 28],
#        [26, 'Male', 29, 28],
#        [27, 'Female', 45, 28],
#        [28, 'Male', 35, 28],
#        [29, 'Female', 40, 29],
#        [30, 'Female', 23, 29],
#        [31, 'Male', 60, 30],
# ...

# %%
y = dataset.iloc[:,4].values
y
# Out:
# array([39, 81,  6, 77, 40, 76,  6, 94,  3, 72, 14, 99, 15, 77, 13, 79, 35,
#        66, 29, 98, 35, 73,  5, 73, 14, 82, 32, 61, 31, 87,  4, 73,  4, 92,
#        14, 81, 17, 73, 26, 75, 35, 92, 36, 61, 28, 65, 55, 47, 42, 42, 52,
#        60, 54, 60, 45, 41, 50, 46, 51, 46, 56, 55, 52, 59, 51, 59, 50, 48,
#        59, 47, 55, 42, 49, 56, 47, 54, 53, 48, 52, 42, 51, 55, 41, 44, 57,
#        46, 58, 55, 60, 46, 55, 41, 49, 40, 42, 52, 47, 50, 42, 49, 41, 48,
#        59, 55, 56, 42, 50, 46, 43, 48, 52, 54, 42, 46, 48, 50, 43, 59, 43,
#        57, 56, 40, 58, 91, 29, 77, 35, 95, 11, 75,  9, 75, 34, 71,  5, 88,
#         7, 73, 10, 72,  5, 93, 40, 87, 12, 97, 36, 74, 22, 90, 17, 88, 20,
#        76, 16, 89,  1, 78,  1, 73, 35, 83,  5, 93, 26, 75, 20, 95, 27, 63,
#        13, 75, 10, 92, 13, 86, 15, 69, 14, 90, 32, 86, 15, 88, 39, 97, 24,
#        68, 17, 85, 23, 69,  8, 91, 16, 79, 28, 74, 18, 83], dtype=int64)

# %%
data = pd.read_csv(r'C:\Users\Bhargav Patel\Desktop\Machine learning_jupyter_notebook\Machine_Learning_Data_Preprocessing_Python-master\Sample_real_estate_data.csv')
print(data['ST_NUM'].isnull())  # it consider empty cell and NA cell  both as null...
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# Name: ST_NUM, dtype: bool

# %%
# to fill unappropriate cell with NAN
missing_values = ["n/a", "na", "--"]  #this values are non-stander values which are available in our data
# we don't need to add "NA" in missing value list because panda automatically consider it as non-standered value.
data1 = pd.read_csv(r'C:\Users\Bhargav Patel\Desktop\Machine learning_jupyter_notebook\Machine_Learning_Data_Preprocessing_Python-master\Sample_real_estate_data.csv', na_values = missing_values)
data1
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
print(data.isnull().sum())
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    2
# NUM_BATH        1
# SQ_FT           1
# dtype: int64

# %%
# use of imputer to add mean value at null cells
from sklearn.preprocessing import Imputer

x = data1.iloc[:,:-1].values
y = data1.iloc[:,6]

imput = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)  # axis=0  because we apply it on collumn
imput = imput.fit(x[:,1:2])
x[:,1:2] = imput.transform(x[:, 1:2])
x[:,1:2]
# Out:
# C:\Users\Bhargav Patel\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# array([[104.0],
#        [197.0],
#        [191.42857142857142],
#        [201.0],
#        [203.0],
#        [207.0],
#        [191.42857142857142],
#        [213.0],
#        [215.0]], dtype=object)

# %%
# use of imputer to add median value at null cells
median = data1['NUM_BEDROOMS'].median()
data1['NUM_BEDROOMS'].fillna(median, inplace=True)
data1
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           2.5        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           2.5        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           2.5        2  1800.0

# %%
from sklearn.preprocessing import LableEncoder
